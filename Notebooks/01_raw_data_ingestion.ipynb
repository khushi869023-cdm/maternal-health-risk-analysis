# %% [markdown]
# ## Notebook 1 : Raw Data Ingestion
# This notebook loads the raw maternal health dataset and performs an initial sanity check.
# No cleaning, transformation, or validation logic is applied.
# All observations are recorded without modifying the original data.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:/maternal-health-risk-analysis/maternal_health.csv")
df.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
df.shape
# Out:
# (1014, 7)

# %% [markdown]
# Number of rows : 1014<br>
# Number of columns : 7

# %%
df.columns
# Out:
# Index(['Age', 'SystolicBP', 'DiastolicBP', 'BS', 'BodyTemp', 'HeartRate',
#        'RiskLevel'],
#       dtype='object')

# %% [markdown]
# # Column name
# - Age
# - SystolicBP
# - DiastolicBP
# - BS
# - BodyTemp
# - HeartRate
# - RiskLevel

# %%
df.dtypes
# Out:
# Age              int64
# SystolicBP       int64
# DiastolicBP      int64
# BS             float64
# BodyTemp       float64
# HeartRate        int64
# RiskLevel       object
# dtype: object

# %%
df.head()
df.tail()
df.sample(5, random_state=42)
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk

# %% [markdown]
# ## Missing values ?

# %%
df.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %% [markdown]
# Which columns have missing data = 0

# %%
(df.isnull().mean() * 100).round(2)
# Out:
# Age            0.0
# SystolicBP     0.0
# DiastolicBP    0.0
# BS             0.0
# BodyTemp       0.0
# HeartRate      0.0
# RiskLevel      0.0
# dtype: float64

# %%
df.describe(include='all')
# Out:
#                 Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count   1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      29.871795   113.198225    76.460552     8.725986    98.665089
# std       13.474386    18.403913    13.885796     3.293532     1.371384
# min       10.000000    70.000000    49.000000     6.000000    98.000000
# 25%       19.000000   100.000000    65.000000     6.900000    98.000000
# 50%       26.000000   120.000000    80.000000     7.500000    98.000000
# 75%       39.000000   120.000000    90.000000     8.000000    98.000000
# max       70.000000   160.000000   100.000000    19.000000   103.000000
#
#           HeartRate RiskLevel
# count   1014.000000      1014
# unique          NaN         3
# ...

# %% [markdown]
# No cleaning, validation, or transformation has been applied in this notebook.
# All findings are observational and inform later validation steps.
